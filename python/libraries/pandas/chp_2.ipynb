# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. TSV file - Tab Seprated File

# %%
df = pd.read_table("file_name.tsv")  #sep = "\t"
df

# %%
df.head(10)     #first 10 values of the table

# %%
df.tail(10)     # last 10 values of the table

# %% [markdown]
# 2. CSV file - Comma Seprated File

# %%
df = pd.read_table("file_name.csv", sep = ",")
df.head()

# %%
#or
df = pd.read_csv("file_name.csv")
df.head()

# %% [markdown]
# 3. Excel File

# %%
# !pip install xlrd    #xl - excel, rd - read

# %%
# !pip install openpyxl   #open py - python, xl - excel

# %%
df = pd.read_excel('file_name.xlsx', sheet_name = 'Sheet1')
df.head()

# %%
#or
df = pd.read_excel('file_name.xlsx', 0)    # 0 represents Sheet1
df.head()

# %% [markdown]
# 4. PSV file

# %%
df = pd.read_table("file_name.user", sep = "|")
df.head

# %%
col = ["User ID", "Age", "Gender", "Occupation", "Pin Code"]
df = pd.read_table("file_name.user", sep = "|", names = col)
df.head()
